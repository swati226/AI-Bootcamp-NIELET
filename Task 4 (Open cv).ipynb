# %%
import cv2
from google.colab.patches import cv2_imshow

# Load and display image
image = cv2.imread('/content/swati.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=285x177>
